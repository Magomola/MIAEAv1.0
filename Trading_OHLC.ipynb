# %% [markdown]
# <a href="https://colab.research.google.com/github/Magomola/MIAEAv1.0/blob/main/Trading_OHLC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#This is a Case study phase#
#Symbol: $GU
#Methodology: Scalping momentum tf alignment

# %%
#importing the OHLC data
import pandas as pd
from google.colab import files
